# %% [markdown]
# # read dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

creditcard = pd.read_csv('./creditcard.csv',header=1)

# %%
creditcard.shape
# Out:
# (30000, 25)

# %%
creditcard.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
for col in creditcard.columns: 
    print(col)
# Out:
# ID
# LIMIT_BAL
# SEX
# EDUCATION
# MARRIAGE
# AGE
# PAY_0
# PAY_2
# PAY_3
# PAY_4
# PAY_5
# PAY_6
# BILL_AMT1
# BILL_AMT2
# BILL_AMT3
# BILL_AMT4
# BILL_AMT5
# BILL_AMT6
# PAY_AMT1
# PAY_AMT2
# PAY_AMT3
# PAY_AMT4
# PAY_AMT5
# PAY_AMT6
# default payment next month

# %%
creditcard.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
creditcard.head(3)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0                           1
# 1      1000         0      2000                           1
# 2      1000      1000      5000                           0
#
# [3 rows x 25 columns]

# %% [markdown]
# ##clean continuous variables

# %%
creditcard.drop(['ID','SEX','EDUCATION','MARRIAGE'], axis=1, inplace=True)
creditcard.head()
# Out:
#    LIMIT_BAL  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  \
# 0      20000   24      2      2     -1     -1     -2     -2       3913
# 1     120000   26     -1      2      0      0      0      2       2682
# 2      90000   34      0      0      0      0      0      0      29239
# 3      50000   37      0      0      0      0      0      0      46990
# 4      50000   57     -1      0     -1      0      0      0       8617
#
#    BILL_AMT2  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0       3102  ...          0          0          0         0       689
# 1       1725  ...       3272       3455       3261         0      1000
# 2      14027  ...      14331      14948      15549      1518      1500
# 3      48233  ...      28314      28959      29547      2000      2019
# 4       5670  ...      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
creditcard['topay'] = creditcard['PAY_0'] + creditcard['PAY_2'] +creditcard['PAY_3']+creditcard['PAY_4'] + creditcard['PAY_5'] + creditcard['PAY_6']

# %%
creditcard.drop(['PAY_0','PAY_2','PAY_3','PAY_4','PAY_5','PAY_6'], axis=1, inplace=True)
creditcard.head()
# Out:
#    LIMIT_BAL  AGE  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0      20000   24       3913       3102        689          0          0
# 1     120000   26       2682       1725       2682       3272       3455
# 2      90000   34      29239      14027      13559      14331      14948
# 3      50000   37      46990      48233      49291      28314      28959
# 4      50000   57       8617       5670      35835      20940      19146
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0          0         0       689         0         0         0         0
# 1       3261         0      1000      1000      1000         0      2000
# 2      15549      1518      1500      1000      1000      1000      5000
# 3      29547      2000      2019      1200      1100      1069      1000
# 4      19131      2000     36681     10000      9000       689       679
#
#    default payment next month  topay
# 0                           1     -2
# ...

# %%
creditcard['BILLAMT'] = creditcard['BILL_AMT1'] + creditcard['BILL_AMT2'] +creditcard['BILL_AMT3']+creditcard['BILL_AMT4'] + creditcard['BILL_AMT5'] + creditcard['BILL_AMT6']

# %%
creditcard.drop(['BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6'], axis=1, inplace=True)
creditcard.head()
# Out:
#    LIMIT_BAL  AGE  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0      20000   24         0       689         0         0         0         0
# 1     120000   26         0      1000      1000      1000         0      2000
# 2      90000   34      1518      1500      1000      1000      1000      5000
# 3      50000   37      2000      2019      1200      1100      1069      1000
# 4      50000   57      2000     36681     10000      9000       689       679
#
#    default payment next month  topay  BILLAMT
# 0                           1     -2     7704
# 1                           1      3    17077
# 2                           0      0   101653
# 3                           0      0   231334
# 4                           0     -2   109339

# %%
creditcard['PAYMENT'] = creditcard['PAY_AMT1'] + creditcard['PAY_AMT2'] +creditcard['PAY_AMT3']+creditcard['PAY_AMT4'] + creditcard['PAY_AMT5'] + creditcard['PAY_AMT6']

# %%
creditcard.drop(['PAY_AMT1','PAY_AMT2','PAY_AMT3','PAY_AMT4','PAY_AMT5','PAY_AMT6'], axis=1, inplace=True)
creditcard.head()
# Out:
#    LIMIT_BAL  AGE  default payment next month  topay  BILLAMT  PAYMENT
# 0      20000   24                           1     -2     7704      689
# 1     120000   26                           1      3    17077     5000
# 2      90000   34                           0      0   101653    11018
# 3      50000   37                           0      0   231334     8388
# 4      50000   57                           0     -2   109339    59049

# %%
creditcard['BILLAMT'].mean()
# Out:
# 269861.6712

# %%
creditcard['PAYMENT'].mean()
# Out:
# 31651.392566666666

# %% [markdown]
# # clean categorical data

# %%
creditcard.isnull().sum()
# Out:
# LIMIT_BAL                     0
# AGE                           0
# default payment next month    0
# topay                         0
# BILLAMT                       0
# PAYMENT                       0
# dtype: int64

# %% [markdown]
# ## no missing values

# %% [markdown]
# #  fitting logistic regression

# %%
from sklearn.model_selection import train_test_split

# %%
features = creditcard.drop('default payment next month', axis=1)
labels = creditcard['default payment next month']

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.3, random_state=42)

# %%
for dataset in [y_train, y_test]:
    print(round(len(dataset) / len(labels), 2))
# Out:
# 0.7
# 0.3

# %%
X_train.to_csv('./traincredit_features.csv', index=False)
X_test.to_csv('./testcredit_features.csv', index=False)

y_train.to_csv('./traincredit_labels.csv', index=False)
y_test.to_csv('./testcredit_labels.csv', index=False)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)

tr_features = pd.read_csv('./traincredit_features.csv')
tr_labels = pd.read_csv('./traincredit_labels.csv')

# %%
lr = LogisticRegression()
lr.fit(tr_features, tr_labels.values.ravel())
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(lr.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.78

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[7040    0]
#  [1960    0]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88      7040
#            1       0.00      0.00      0.00      1960
#
#     accuracy                           0.78      9000
#    macro avg       0.39      0.50      0.44      9000
# weighted avg       0.61      0.78      0.69      9000
# C:\Users\nehab\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, lr.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, lr.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
